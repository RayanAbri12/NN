# %%
import numpy as np
import torch 
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset

# %%
# Read Diabetes Dataset
_data = pd.read_csv('diabetes.csv')

# %%
#preprocessing
# X : extract all rows and columns except last one
# Y : last column for labeling 
# Numpy'a cevirilmesi

X = _data.iloc[:,0:-1]
Y_string = list(_data.iloc[:,-1])
# It is needed to convert string labels to int 
Y_int = []
for s in Y_string:
    if s == 'positive':
        Y_int.append(1)
    else:
        Y_int.append(0)
# It is needed to convert int to numpy array after that we can convert numpy to torch tensors
Y = np.array(Y_int, dtype = 'float64')

# %%
# Normalization Part, it is needed to have the features with the same range of values. For exampel (-1,1)
# for that propose x - mean/standar_deviation
# create StandardScaler object from sklearn
_sc = StandardScaler()
X = _sc.fit_transform(X)
# convert numpy array to torch tensor
x = torch.tensor(X)
y = torch.tensor(Y)
# we need add dimention in the y label becasue of chooing right shape, we need a single value in each row
y = y.unsqueeze(1)
print(y.shape)
print(x.shape)
# Out:
# torch.Size([768, 1])
# torch.Size([768, 7])

# %%
y.shape
# Out:
# torch.Size([768, 1])

# %%
#loading data to dataloader for bach processing and shuffling
class Dataset(Dataset):
    
    def __init__(self,x,y):
        self.x = x
        self.y = y
    
    def __getitem__(self,index):
        #getting one item from the dataset
        return self.x[index], self.y[index]
    
    def __len__(self):
        return len(self.x)
    
# create object from the Dataset class
_dataset = Dataset(x,y)
print(len(_dataset))
# Out:
# 768

# %%
train_loader = torch.utils.data.DataLoader(dataset = _dataset, batch_size = 32, shuffle = True)
# the detail info of the Data loader
print("Batch size value is {}".format(len(train_loader)))
for (x,y) in train_loader:
    print("one batch information")
    print("Data: ------->  {}".format(x.shape))
    print("Label: ------->  {}".format(y.shape))
    break
# Out:
# Batch size value is 24
# one batch information
# Data: ------->  torch.Size([32, 7])
# Label: ------->  torch.Size([32, 1])

# %%
# building the Model
class MODEL(nn.Module):
    def __init__(self, input_features):
        super(MODEL,self).__init__()
        self._InputLayer = nn.Linear(input_features,5)
        self._2thLayer = nn.Linear(5,4)
        self._3thLayer = nn.Linear(4,3)
        self._OutputLayer = nn.Linear(3,1)
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
        self.relu = nn.ReLU()

    def forward(self,x):
        out = self._InputLayer(x)
        out = self.tanh(out)
        out = self._2thLayer(out)
        out = self.tanh(out)
        out = self._3thLayer(out)
        out = self.tanh(out)
        out = self._OutputLayer(out)
        out = self.sigmoid(out)
        return out

# %%
# creating the network (instance of the MODEL class)
_network = MODEL(x.shape[1])
# in binary cross entropy the input and output should have the same shape
# size_average = True -- the losses are averaged over observation for each minibatch
Loos_func = torch.nn.BCELoss(size_average = True)
_Optimizer = torch.optim.SGD(_network.parameters(), lr= 0.1, momentum= 0.9)
_network
# Out:
# /Users/rayanabri/opt/anaconda3/envs/pytorchE/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# MODEL(
#   (_InputLayer): Linear(in_features=7, out_features=5, bias=True)
#   (_2thLayer): Linear(in_features=5, out_features=4, bias=True)
#   (_3thLayer): Linear(in_features=4, out_features=3, bias=True)
#   (_OutputLayer): Linear(in_features=3, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (tanh): Tanh()
#   (relu): ReLU()
# )

# %%
_epochs = 500
for epoch in range(500):
    for inputs,labels in train_loader:
        inputs = inputs.float()
        labels = labels.float()
        # Forward Propagation
        _outputs = _network(inputs)
        # loss calculation
        _Loss = Loos_func(_outputs,labels)
        # clear the gradient buffer (you need to do it manually in pytorch)
        _Optimizer.zero_grad()
        # back propagation
        _Loss.backward()
        # update weights W <- W - lr*gradient
        _Optimizer.step()

    # Accuracy Calculation. Since we are using a sigmoid, we will need to perform some thresholding
    OUT = (_outputs>0.5).float()
    # Accuracy: (output == labels).float().sum() / output.shape[0]
    _Acc = (OUT == labels).float().mean()
    # print statistics
    print("Epoch {}/{}, Train_Loss: {:.2f}, Train_Accuracy: {:.2f}".format(epoch+1, _epochs, _Loss, _Acc))
# Out:
# Epoch 1/500, Train_Loss: 0.59, Train_Accuracy: 0.72
# Epoch 2/500, Train_Loss: 0.56, Train_Accuracy: 0.72
# Epoch 3/500, Train_Loss: 0.60, Train_Accuracy: 0.78
# Epoch 4/500, Train_Loss: 0.72, Train_Accuracy: 0.66
# Epoch 5/500, Train_Loss: 0.52, Train_Accuracy: 0.81
# Epoch 6/500, Train_Loss: 0.53, Train_Accuracy: 0.78
# Epoch 7/500, Train_Loss: 0.59, Train_Accuracy: 0.62
# Epoch 8/500, Train_Loss: 0.49, Train_Accuracy: 0.78
# Epoch 9/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 10/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 11/500, Train_Loss: 0.44, Train_Accuracy: 0.75
# Epoch 12/500, Train_Loss: 0.53, Train_Accuracy: 0.69
# Epoch 13/500, Train_Loss: 0.47, Train_Accuracy: 0.84
# Epoch 14/500, Train_Loss: 0.51, Train_Accuracy: 0.78
# Epoch 15/500, Train_Loss: 0.62, Train_Accuracy: 0.75
# Epoch 16/500, Train_Loss: 0.52, Train_Accuracy: 0.66
# Epoch 17/500, Train_Loss: 0.55, Train_Accuracy: 0.72
# Epoch 18/500, Train_Loss: 0.42, Train_Accuracy: 0.84
# Epoch 19/500, Train_Loss: 0.45, Train_Accuracy: 0.78
# Epoch 20/500, Train_Loss: 0.30, Train_Accuracy: 0.94
# Epoch 21/500, Train_Loss: 0.37, Train_Accuracy: 0.88
# Epoch 22/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 23/500, Train_Loss: 0.54, Train_Accuracy: 0.69
# Epoch 24/500, Train_Loss: 0.38, Train_Accuracy: 0.84
# Epoch 25/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 26/500, Train_Loss: 0.69, Train_Accuracy: 0.66
# Epoch 27/500, Train_Loss: 0.31, Train_Accuracy: 0.88
# Epoch 28/500, Train_Loss: 0.41, Train_Accuracy: 0.84
# Epoch 29/500, Train_Loss: 0.37, Train_Accuracy: 0.88
# Epoch 30/500, Train_Loss: 0.30, Train_Accuracy: 0.91
# Epoch 31/500, Train_Loss: 0.50, Train_Accuracy: 0.75
# Epoch 32/500, Train_Loss: 0.54, Train_Accuracy: 0.72
# Epoch 33/500, Train_Loss: 0.49, Train_Accuracy: 0.69
# Epoch 34/500, Train_Loss: 0.34, Train_Accuracy: 0.78
# Epoch 35/500, Train_Loss: 0.53, Train_Accuracy: 0.72
# Epoch 36/500, Train_Loss: 0.37, Train_Accuracy: 0.78
# Epoch 37/500, Train_Loss: 0.30, Train_Accuracy: 0.88
# Epoch 38/500, Train_Loss: 0.51, Train_Accuracy: 0.66
# Epoch 39/500, Train_Loss: 0.46, Train_Accuracy: 0.81
# Epoch 40/500, Train_Loss: 0.41, Train_Accuracy: 0.69
# Epoch 41/500, Train_Loss: 0.41, Train_Accuracy: 0.84
# Epoch 42/500, Train_Loss: 0.56, Train_Accuracy: 0.75
# Epoch 43/500, Train_Loss: 0.42, Train_Accuracy: 0.84
# Epoch 44/500, Train_Loss: 0.42, Train_Accuracy: 0.72
# Epoch 45/500, Train_Loss: 0.50, Train_Accuracy: 0.72
# Epoch 46/500, Train_Loss: 0.38, Train_Accuracy: 0.75
# Epoch 47/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 48/500, Train_Loss: 0.55, Train_Accuracy: 0.72
# Epoch 49/500, Train_Loss: 0.45, Train_Accuracy: 0.81
# Epoch 50/500, Train_Loss: 0.56, Train_Accuracy: 0.62
# Epoch 51/500, Train_Loss: 0.50, Train_Accuracy: 0.62
# Epoch 52/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 53/500, Train_Loss: 0.51, Train_Accuracy: 0.72
# Epoch 54/500, Train_Loss: 0.29, Train_Accuracy: 0.94
# Epoch 55/500, Train_Loss: 0.39, Train_Accuracy: 0.81
# Epoch 56/500, Train_Loss: 0.34, Train_Accuracy: 0.78
# Epoch 57/500, Train_Loss: 0.45, Train_Accuracy: 0.78
# Epoch 58/500, Train_Loss: 0.31, Train_Accuracy: 0.78
# Epoch 59/500, Train_Loss: 0.29, Train_Accuracy: 0.88
# Epoch 60/500, Train_Loss: 0.53, Train_Accuracy: 0.75
# Epoch 61/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 62/500, Train_Loss: 0.51, Train_Accuracy: 0.81
# Epoch 63/500, Train_Loss: 0.37, Train_Accuracy: 0.78
# Epoch 64/500, Train_Loss: 0.43, Train_Accuracy: 0.72
# Epoch 65/500, Train_Loss: 0.55, Train_Accuracy: 0.66
# Epoch 66/500, Train_Loss: 0.31, Train_Accuracy: 0.88
# Epoch 67/500, Train_Loss: 0.39, Train_Accuracy: 0.84
# Epoch 68/500, Train_Loss: 0.63, Train_Accuracy: 0.62
# Epoch 69/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 70/500, Train_Loss: 0.50, Train_Accuracy: 0.78
# Epoch 71/500, Train_Loss: 0.71, Train_Accuracy: 0.66
# Epoch 72/500, Train_Loss: 0.38, Train_Accuracy: 0.84
# Epoch 73/500, Train_Loss: 0.47, Train_Accuracy: 0.78
# Epoch 74/500, Train_Loss: 0.32, Train_Accuracy: 0.91
# Epoch 75/500, Train_Loss: 0.39, Train_Accuracy: 0.81
# Epoch 76/500, Train_Loss: 0.43, Train_Accuracy: 0.81
# Epoch 77/500, Train_Loss: 0.47, Train_Accuracy: 0.78
# Epoch 78/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 79/500, Train_Loss: 0.37, Train_Accuracy: 0.78
# Epoch 80/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 81/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 82/500, Train_Loss: 0.29, Train_Accuracy: 0.81
# Epoch 83/500, Train_Loss: 0.49, Train_Accuracy: 0.69
# Epoch 84/500, Train_Loss: 0.36, Train_Accuracy: 0.78
# Epoch 85/500, Train_Loss: 0.51, Train_Accuracy: 0.69
# Epoch 86/500, Train_Loss: 0.43, Train_Accuracy: 0.75
# Epoch 87/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 88/500, Train_Loss: 0.48, Train_Accuracy: 0.81
# Epoch 89/500, Train_Loss: 0.45, Train_Accuracy: 0.69
# Epoch 90/500, Train_Loss: 0.37, Train_Accuracy: 0.78
# Epoch 91/500, Train_Loss: 0.37, Train_Accuracy: 0.84
# Epoch 92/500, Train_Loss: 0.53, Train_Accuracy: 0.75
# Epoch 93/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 94/500, Train_Loss: 0.61, Train_Accuracy: 0.69
# Epoch 95/500, Train_Loss: 0.52, Train_Accuracy: 0.75
# Epoch 96/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 97/500, Train_Loss: 0.38, Train_Accuracy: 0.78
# Epoch 98/500, Train_Loss: 0.47, Train_Accuracy: 0.69
# Epoch 99/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 100/500, Train_Loss: 0.52, Train_Accuracy: 0.69
# Epoch 101/500, Train_Loss: 0.40, Train_Accuracy: 0.75
# Epoch 102/500, Train_Loss: 0.29, Train_Accuracy: 0.88
# Epoch 103/500, Train_Loss: 0.39, Train_Accuracy: 0.84
# Epoch 104/500, Train_Loss: 0.47, Train_Accuracy: 0.72
# Epoch 105/500, Train_Loss: 0.43, Train_Accuracy: 0.88
# Epoch 106/500, Train_Loss: 0.25, Train_Accuracy: 0.88
# Epoch 107/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 108/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 109/500, Train_Loss: 0.48, Train_Accuracy: 0.72
# Epoch 110/500, Train_Loss: 0.41, Train_Accuracy: 0.81
# Epoch 111/500, Train_Loss: 0.40, Train_Accuracy: 0.69
# Epoch 112/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 113/500, Train_Loss: 0.55, Train_Accuracy: 0.69
# Epoch 114/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 115/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 116/500, Train_Loss: 0.34, Train_Accuracy: 0.88
# Epoch 117/500, Train_Loss: 0.46, Train_Accuracy: 0.72
# Epoch 118/500, Train_Loss: 0.29, Train_Accuracy: 0.94
# Epoch 119/500, Train_Loss: 0.42, Train_Accuracy: 0.81
# Epoch 120/500, Train_Loss: 0.39, Train_Accuracy: 0.72
# Epoch 121/500, Train_Loss: 0.60, Train_Accuracy: 0.72
# Epoch 122/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 123/500, Train_Loss: 0.35, Train_Accuracy: 0.81
# Epoch 124/500, Train_Loss: 0.49, Train_Accuracy: 0.75
# Epoch 125/500, Train_Loss: 0.44, Train_Accuracy: 0.75
# Epoch 126/500, Train_Loss: 0.38, Train_Accuracy: 0.84
# Epoch 127/500, Train_Loss: 0.26, Train_Accuracy: 0.84
# Epoch 128/500, Train_Loss: 0.41, Train_Accuracy: 0.75
# Epoch 129/500, Train_Loss: 0.40, Train_Accuracy: 0.75
# Epoch 130/500, Train_Loss: 0.29, Train_Accuracy: 0.84
# Epoch 131/500, Train_Loss: 0.35, Train_Accuracy: 0.84
# Epoch 132/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 133/500, Train_Loss: 0.34, Train_Accuracy: 0.88
# Epoch 134/500, Train_Loss: 0.40, Train_Accuracy: 0.78
# Epoch 135/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 136/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 137/500, Train_Loss: 0.33, Train_Accuracy: 0.84
# Epoch 138/500, Train_Loss: 0.48, Train_Accuracy: 0.72
# Epoch 139/500, Train_Loss: 0.45, Train_Accuracy: 0.66
# Epoch 140/500, Train_Loss: 0.47, Train_Accuracy: 0.81
# Epoch 141/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 142/500, Train_Loss: 0.47, Train_Accuracy: 0.69
# Epoch 143/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 144/500, Train_Loss: 0.35, Train_Accuracy: 0.78
# Epoch 145/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 146/500, Train_Loss: 0.51, Train_Accuracy: 0.66
# Epoch 147/500, Train_Loss: 0.37, Train_Accuracy: 0.69
# Epoch 148/500, Train_Loss: 0.53, Train_Accuracy: 0.66
# Epoch 149/500, Train_Loss: 0.59, Train_Accuracy: 0.75
# Epoch 150/500, Train_Loss: 0.53, Train_Accuracy: 0.81
# Epoch 151/500, Train_Loss: 0.43, Train_Accuracy: 0.75
# Epoch 152/500, Train_Loss: 0.28, Train_Accuracy: 0.84
# Epoch 153/500, Train_Loss: 0.62, Train_Accuracy: 0.72
# Epoch 154/500, Train_Loss: 0.54, Train_Accuracy: 0.72
# Epoch 155/500, Train_Loss: 0.33, Train_Accuracy: 0.81
# Epoch 156/500, Train_Loss: 0.51, Train_Accuracy: 0.75
# Epoch 157/500, Train_Loss: 0.26, Train_Accuracy: 0.84
# Epoch 158/500, Train_Loss: 0.29, Train_Accuracy: 0.88
# Epoch 159/500, Train_Loss: 0.27, Train_Accuracy: 0.84
# Epoch 160/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 161/500, Train_Loss: 0.52, Train_Accuracy: 0.75
# Epoch 162/500, Train_Loss: 0.28, Train_Accuracy: 0.84
# Epoch 163/500, Train_Loss: 0.38, Train_Accuracy: 0.78
# Epoch 164/500, Train_Loss: 0.35, Train_Accuracy: 0.88
# Epoch 165/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 166/500, Train_Loss: 0.33, Train_Accuracy: 0.84
# Epoch 167/500, Train_Loss: 0.33, Train_Accuracy: 0.81
# Epoch 168/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 169/500, Train_Loss: 0.41, Train_Accuracy: 0.84
# Epoch 170/500, Train_Loss: 0.45, Train_Accuracy: 0.84
# Epoch 171/500, Train_Loss: 0.53, Train_Accuracy: 0.69
# Epoch 172/500, Train_Loss: 0.50, Train_Accuracy: 0.81
# Epoch 173/500, Train_Loss: 0.47, Train_Accuracy: 0.72
# Epoch 174/500, Train_Loss: 0.74, Train_Accuracy: 0.62
# Epoch 175/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 176/500, Train_Loss: 0.39, Train_Accuracy: 0.84
# Epoch 177/500, Train_Loss: 0.37, Train_Accuracy: 0.84
# Epoch 178/500, Train_Loss: 0.51, Train_Accuracy: 0.78
# Epoch 179/500, Train_Loss: 0.34, Train_Accuracy: 0.81
# Epoch 180/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 181/500, Train_Loss: 0.46, Train_Accuracy: 0.72
# Epoch 182/500, Train_Loss: 0.39, Train_Accuracy: 0.81
# Epoch 183/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 184/500, Train_Loss: 0.35, Train_Accuracy: 0.81
# Epoch 185/500, Train_Loss: 0.44, Train_Accuracy: 0.78
# Epoch 186/500, Train_Loss: 0.32, Train_Accuracy: 0.84
# Epoch 187/500, Train_Loss: 0.47, Train_Accuracy: 0.81
# Epoch 188/500, Train_Loss: 0.44, Train_Accuracy: 0.72
# Epoch 189/500, Train_Loss: 0.54, Train_Accuracy: 0.72
# Epoch 190/500, Train_Loss: 0.47, Train_Accuracy: 0.69
# Epoch 191/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 192/500, Train_Loss: 0.47, Train_Accuracy: 0.78
# Epoch 193/500, Train_Loss: 0.27, Train_Accuracy: 0.88
# Epoch 194/500, Train_Loss: 0.31, Train_Accuracy: 0.88
# Epoch 195/500, Train_Loss: 0.26, Train_Accuracy: 0.84
# Epoch 196/500, Train_Loss: 0.29, Train_Accuracy: 0.91
# Epoch 197/500, Train_Loss: 0.47, Train_Accuracy: 0.81
# Epoch 198/500, Train_Loss: 0.28, Train_Accuracy: 0.84
# Epoch 199/500, Train_Loss: 0.32, Train_Accuracy: 0.81
# Epoch 200/500, Train_Loss: 0.45, Train_Accuracy: 0.78
# Epoch 201/500, Train_Loss: 0.28, Train_Accuracy: 0.88
# Epoch 202/500, Train_Loss: 0.45, Train_Accuracy: 0.81
# Epoch 203/500, Train_Loss: 0.28, Train_Accuracy: 0.88
# Epoch 204/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 205/500, Train_Loss: 0.34, Train_Accuracy: 0.81
# Epoch 206/500, Train_Loss: 0.28, Train_Accuracy: 0.91
# Epoch 207/500, Train_Loss: 0.34, Train_Accuracy: 0.75
# Epoch 208/500, Train_Loss: 0.28, Train_Accuracy: 0.91
# Epoch 209/500, Train_Loss: 0.63, Train_Accuracy: 0.72
# Epoch 210/500, Train_Loss: 0.55, Train_Accuracy: 0.78
# Epoch 211/500, Train_Loss: 0.34, Train_Accuracy: 0.75
# Epoch 212/500, Train_Loss: 0.53, Train_Accuracy: 0.75
# Epoch 213/500, Train_Loss: 0.33, Train_Accuracy: 0.84
# Epoch 214/500, Train_Loss: 0.37, Train_Accuracy: 0.88
# Epoch 215/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 216/500, Train_Loss: 0.28, Train_Accuracy: 0.81
# Epoch 217/500, Train_Loss: 0.40, Train_Accuracy: 0.78
# Epoch 218/500, Train_Loss: 0.43, Train_Accuracy: 0.72
# Epoch 219/500, Train_Loss: 0.40, Train_Accuracy: 0.84
# Epoch 220/500, Train_Loss: 0.29, Train_Accuracy: 0.84
# Epoch 221/500, Train_Loss: 0.45, Train_Accuracy: 0.69
# Epoch 222/500, Train_Loss: 0.42, Train_Accuracy: 0.72
# Epoch 223/500, Train_Loss: 0.40, Train_Accuracy: 0.75
# Epoch 224/500, Train_Loss: 0.32, Train_Accuracy: 0.81
# Epoch 225/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 226/500, Train_Loss: 0.45, Train_Accuracy: 0.81
# Epoch 227/500, Train_Loss: 0.23, Train_Accuracy: 0.94
# Epoch 228/500, Train_Loss: 0.48, Train_Accuracy: 0.75
# Epoch 229/500, Train_Loss: 0.70, Train_Accuracy: 0.62
# Epoch 230/500, Train_Loss: 0.33, Train_Accuracy: 0.81
# Epoch 231/500, Train_Loss: 0.26, Train_Accuracy: 0.84
# Epoch 232/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 233/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 234/500, Train_Loss: 0.43, Train_Accuracy: 0.81
# Epoch 235/500, Train_Loss: 0.46, Train_Accuracy: 0.72
# Epoch 236/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 237/500, Train_Loss: 0.51, Train_Accuracy: 0.66
# Epoch 238/500, Train_Loss: 0.27, Train_Accuracy: 0.88
# Epoch 239/500, Train_Loss: 0.57, Train_Accuracy: 0.69
# Epoch 240/500, Train_Loss: 0.45, Train_Accuracy: 0.84
# Epoch 241/500, Train_Loss: 0.41, Train_Accuracy: 0.81
# Epoch 242/500, Train_Loss: 0.24, Train_Accuracy: 0.91
# Epoch 243/500, Train_Loss: 0.53, Train_Accuracy: 0.66
# Epoch 244/500, Train_Loss: 0.62, Train_Accuracy: 0.69
# Epoch 245/500, Train_Loss: 0.53, Train_Accuracy: 0.78
# Epoch 246/500, Train_Loss: 0.49, Train_Accuracy: 0.69
# Epoch 247/500, Train_Loss: 0.24, Train_Accuracy: 0.88
# Epoch 248/500, Train_Loss: 0.37, Train_Accuracy: 0.75
# Epoch 249/500, Train_Loss: 0.54, Train_Accuracy: 0.72
# Epoch 250/500, Train_Loss: 0.48, Train_Accuracy: 0.75
# Epoch 251/500, Train_Loss: 0.42, Train_Accuracy: 0.69
# Epoch 252/500, Train_Loss: 0.30, Train_Accuracy: 0.88
# Epoch 253/500, Train_Loss: 0.42, Train_Accuracy: 0.75
# Epoch 254/500, Train_Loss: 0.34, Train_Accuracy: 0.81
# Epoch 255/500, Train_Loss: 0.44, Train_Accuracy: 0.81
# Epoch 256/500, Train_Loss: 0.28, Train_Accuracy: 0.91
# Epoch 257/500, Train_Loss: 0.38, Train_Accuracy: 0.81
# Epoch 258/500, Train_Loss: 0.48, Train_Accuracy: 0.78
# Epoch 259/500, Train_Loss: 0.25, Train_Accuracy: 0.91
# Epoch 260/500, Train_Loss: 0.52, Train_Accuracy: 0.72
# Epoch 261/500, Train_Loss: 0.30, Train_Accuracy: 0.81
# Epoch 262/500, Train_Loss: 0.63, Train_Accuracy: 0.75
# Epoch 263/500, Train_Loss: 0.39, Train_Accuracy: 0.88
# Epoch 264/500, Train_Loss: 0.38, Train_Accuracy: 0.75
# Epoch 265/500, Train_Loss: 0.34, Train_Accuracy: 0.88
# Epoch 266/500, Train_Loss: 0.41, Train_Accuracy: 0.75
# Epoch 267/500, Train_Loss: 0.53, Train_Accuracy: 0.69
# Epoch 268/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 269/500, Train_Loss: 0.41, Train_Accuracy: 0.81
# Epoch 270/500, Train_Loss: 0.40, Train_Accuracy: 0.75
# Epoch 271/500, Train_Loss: 0.26, Train_Accuracy: 0.91
# Epoch 272/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 273/500, Train_Loss: 0.50, Train_Accuracy: 0.72
# Epoch 274/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 275/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 276/500, Train_Loss: 0.44, Train_Accuracy: 0.78
# Epoch 277/500, Train_Loss: 0.34, Train_Accuracy: 0.78
# Epoch 278/500, Train_Loss: 0.41, Train_Accuracy: 0.72
# Epoch 279/500, Train_Loss: 0.47, Train_Accuracy: 0.75
# Epoch 280/500, Train_Loss: 0.42, Train_Accuracy: 0.75
# Epoch 281/500, Train_Loss: 0.45, Train_Accuracy: 0.78
# Epoch 282/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 283/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 284/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 285/500, Train_Loss: 0.37, Train_Accuracy: 0.75
# Epoch 286/500, Train_Loss: 0.48, Train_Accuracy: 0.66
# Epoch 287/500, Train_Loss: 0.30, Train_Accuracy: 0.84
# Epoch 288/500, Train_Loss: 0.24, Train_Accuracy: 0.88
# Epoch 289/500, Train_Loss: 0.59, Train_Accuracy: 0.66
# Epoch 290/500, Train_Loss: 0.32, Train_Accuracy: 0.84
# Epoch 291/500, Train_Loss: 0.36, Train_Accuracy: 0.88
# Epoch 292/500, Train_Loss: 0.33, Train_Accuracy: 0.78
# Epoch 293/500, Train_Loss: 0.36, Train_Accuracy: 0.88
# Epoch 294/500, Train_Loss: 0.29, Train_Accuracy: 0.84
# Epoch 295/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 296/500, Train_Loss: 0.53, Train_Accuracy: 0.88
# Epoch 297/500, Train_Loss: 0.36, Train_Accuracy: 0.72
# Epoch 298/500, Train_Loss: 0.49, Train_Accuracy: 0.75
# Epoch 299/500, Train_Loss: 0.23, Train_Accuracy: 0.88
# Epoch 300/500, Train_Loss: 0.48, Train_Accuracy: 0.69
# Epoch 301/500, Train_Loss: 0.47, Train_Accuracy: 0.59
# Epoch 302/500, Train_Loss: 0.42, Train_Accuracy: 0.84
# Epoch 303/500, Train_Loss: 0.59, Train_Accuracy: 0.59
# Epoch 304/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 305/500, Train_Loss: 0.56, Train_Accuracy: 0.69
# Epoch 306/500, Train_Loss: 0.51, Train_Accuracy: 0.69
# Epoch 307/500, Train_Loss: 0.52, Train_Accuracy: 0.75
# Epoch 308/500, Train_Loss: 0.45, Train_Accuracy: 0.72
# Epoch 309/500, Train_Loss: 0.44, Train_Accuracy: 0.72
# Epoch 310/500, Train_Loss: 0.40, Train_Accuracy: 0.72
# Epoch 311/500, Train_Loss: 0.57, Train_Accuracy: 0.66
# Epoch 312/500, Train_Loss: 0.40, Train_Accuracy: 0.78
# Epoch 313/500, Train_Loss: 0.26, Train_Accuracy: 0.94
# Epoch 314/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 315/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 316/500, Train_Loss: 0.36, Train_Accuracy: 0.88
# Epoch 317/500, Train_Loss: 0.23, Train_Accuracy: 0.91
# Epoch 318/500, Train_Loss: 0.33, Train_Accuracy: 0.88
# Epoch 319/500, Train_Loss: 0.38, Train_Accuracy: 0.78
# Epoch 320/500, Train_Loss: 0.47, Train_Accuracy: 0.69
# Epoch 321/500, Train_Loss: 0.47, Train_Accuracy: 0.88
# Epoch 322/500, Train_Loss: 0.40, Train_Accuracy: 0.78
# Epoch 323/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 324/500, Train_Loss: 0.53, Train_Accuracy: 0.72
# Epoch 325/500, Train_Loss: 0.44, Train_Accuracy: 0.81
# Epoch 326/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 327/500, Train_Loss: 0.49, Train_Accuracy: 0.66
# Epoch 328/500, Train_Loss: 0.21, Train_Accuracy: 0.94
# Epoch 329/500, Train_Loss: 0.52, Train_Accuracy: 0.75
# Epoch 330/500, Train_Loss: 0.35, Train_Accuracy: 0.88
# Epoch 331/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 332/500, Train_Loss: 0.37, Train_Accuracy: 0.84
# Epoch 333/500, Train_Loss: 0.53, Train_Accuracy: 0.69
# Epoch 334/500, Train_Loss: 0.35, Train_Accuracy: 0.91
# Epoch 335/500, Train_Loss: 0.39, Train_Accuracy: 0.81
# Epoch 336/500, Train_Loss: 0.41, Train_Accuracy: 0.75
# Epoch 337/500, Train_Loss: 0.42, Train_Accuracy: 0.72
# Epoch 338/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 339/500, Train_Loss: 0.63, Train_Accuracy: 0.59
# Epoch 340/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 341/500, Train_Loss: 0.48, Train_Accuracy: 0.69
# Epoch 342/500, Train_Loss: 0.44, Train_Accuracy: 0.84
# Epoch 343/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 344/500, Train_Loss: 0.31, Train_Accuracy: 0.91
# Epoch 345/500, Train_Loss: 0.35, Train_Accuracy: 0.78
# Epoch 346/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 347/500, Train_Loss: 0.75, Train_Accuracy: 0.66
# Epoch 348/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 349/500, Train_Loss: 0.46, Train_Accuracy: 0.78
# Epoch 350/500, Train_Loss: 0.40, Train_Accuracy: 0.84
# Epoch 351/500, Train_Loss: 0.33, Train_Accuracy: 0.88
# Epoch 352/500, Train_Loss: 0.29, Train_Accuracy: 0.88
# Epoch 353/500, Train_Loss: 0.54, Train_Accuracy: 0.75
# Epoch 354/500, Train_Loss: 0.32, Train_Accuracy: 0.78
# Epoch 355/500, Train_Loss: 0.33, Train_Accuracy: 0.84
# Epoch 356/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 357/500, Train_Loss: 0.41, Train_Accuracy: 0.81
# Epoch 358/500, Train_Loss: 0.33, Train_Accuracy: 0.81
# Epoch 359/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 360/500, Train_Loss: 0.57, Train_Accuracy: 0.78
# Epoch 361/500, Train_Loss: 0.42, Train_Accuracy: 0.81
# Epoch 362/500, Train_Loss: 0.46, Train_Accuracy: 0.69
# Epoch 363/500, Train_Loss: 0.52, Train_Accuracy: 0.78
# Epoch 364/500, Train_Loss: 0.38, Train_Accuracy: 0.75
# Epoch 365/500, Train_Loss: 0.31, Train_Accuracy: 0.75
# Epoch 366/500, Train_Loss: 0.31, Train_Accuracy: 0.94
# Epoch 367/500, Train_Loss: 0.27, Train_Accuracy: 0.84
# Epoch 368/500, Train_Loss: 0.40, Train_Accuracy: 0.75
# Epoch 369/500, Train_Loss: 0.35, Train_Accuracy: 0.72
# Epoch 370/500, Train_Loss: 0.59, Train_Accuracy: 0.75
# Epoch 371/500, Train_Loss: 0.32, Train_Accuracy: 0.84
# Epoch 372/500, Train_Loss: 0.39, Train_Accuracy: 0.72
# Epoch 373/500, Train_Loss: 0.77, Train_Accuracy: 0.66
# Epoch 374/500, Train_Loss: 0.54, Train_Accuracy: 0.75
# Epoch 375/500, Train_Loss: 0.27, Train_Accuracy: 0.91
# Epoch 376/500, Train_Loss: 0.36, Train_Accuracy: 0.81
# Epoch 377/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 378/500, Train_Loss: 0.62, Train_Accuracy: 0.72
# Epoch 379/500, Train_Loss: 0.20, Train_Accuracy: 0.94
# Epoch 380/500, Train_Loss: 0.53, Train_Accuracy: 0.75
# Epoch 381/500, Train_Loss: 0.49, Train_Accuracy: 0.72
# Epoch 382/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 383/500, Train_Loss: 0.34, Train_Accuracy: 0.88
# Epoch 384/500, Train_Loss: 0.80, Train_Accuracy: 0.59
# Epoch 385/500, Train_Loss: 0.45, Train_Accuracy: 0.72
# Epoch 386/500, Train_Loss: 0.38, Train_Accuracy: 0.81
# Epoch 387/500, Train_Loss: 0.36, Train_Accuracy: 0.75
# Epoch 388/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 389/500, Train_Loss: 0.27, Train_Accuracy: 0.88
# Epoch 390/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 391/500, Train_Loss: 0.33, Train_Accuracy: 0.72
# Epoch 392/500, Train_Loss: 0.35, Train_Accuracy: 0.91
# Epoch 393/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 394/500, Train_Loss: 0.39, Train_Accuracy: 0.94
# Epoch 395/500, Train_Loss: 0.37, Train_Accuracy: 0.84
# Epoch 396/500, Train_Loss: 0.34, Train_Accuracy: 0.81
# Epoch 397/500, Train_Loss: 0.38, Train_Accuracy: 0.84
# Epoch 398/500, Train_Loss: 0.53, Train_Accuracy: 0.81
# Epoch 399/500, Train_Loss: 0.48, Train_Accuracy: 0.81
# Epoch 400/500, Train_Loss: 0.42, Train_Accuracy: 0.78
# Epoch 401/500, Train_Loss: 0.38, Train_Accuracy: 0.78
# Epoch 402/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 403/500, Train_Loss: 0.31, Train_Accuracy: 0.88
# Epoch 404/500, Train_Loss: 0.37, Train_Accuracy: 0.88
# Epoch 405/500, Train_Loss: 0.61, Train_Accuracy: 0.69
# Epoch 406/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 407/500, Train_Loss: 0.60, Train_Accuracy: 0.66
# Epoch 408/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 409/500, Train_Loss: 0.43, Train_Accuracy: 0.88
# Epoch 410/500, Train_Loss: 0.47, Train_Accuracy: 0.72
# Epoch 411/500, Train_Loss: 0.31, Train_Accuracy: 0.88
# Epoch 412/500, Train_Loss: 0.30, Train_Accuracy: 0.84
# Epoch 413/500, Train_Loss: 0.45, Train_Accuracy: 0.81
# Epoch 414/500, Train_Loss: 0.31, Train_Accuracy: 0.81
# Epoch 415/500, Train_Loss: 0.46, Train_Accuracy: 0.84
# Epoch 416/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 417/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 418/500, Train_Loss: 0.33, Train_Accuracy: 0.84
# Epoch 419/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 420/500, Train_Loss: 0.41, Train_Accuracy: 0.78
# Epoch 421/500, Train_Loss: 0.72, Train_Accuracy: 0.66
# Epoch 422/500, Train_Loss: 0.44, Train_Accuracy: 0.66
# Epoch 423/500, Train_Loss: 0.59, Train_Accuracy: 0.84
# Epoch 424/500, Train_Loss: 0.49, Train_Accuracy: 0.78
# Epoch 425/500, Train_Loss: 0.45, Train_Accuracy: 0.66
# Epoch 426/500, Train_Loss: 0.37, Train_Accuracy: 0.78
# Epoch 427/500, Train_Loss: 0.35, Train_Accuracy: 0.84
# Epoch 428/500, Train_Loss: 0.36, Train_Accuracy: 0.72
# Epoch 429/500, Train_Loss: 0.36, Train_Accuracy: 0.78
# Epoch 430/500, Train_Loss: 0.30, Train_Accuracy: 0.88
# Epoch 431/500, Train_Loss: 0.52, Train_Accuracy: 0.78
# Epoch 432/500, Train_Loss: 0.23, Train_Accuracy: 0.91
# Epoch 433/500, Train_Loss: 0.39, Train_Accuracy: 0.75
# Epoch 434/500, Train_Loss: 0.30, Train_Accuracy: 0.81
# Epoch 435/500, Train_Loss: 0.58, Train_Accuracy: 0.62
# Epoch 436/500, Train_Loss: 0.40, Train_Accuracy: 0.84
# Epoch 437/500, Train_Loss: 0.52, Train_Accuracy: 0.72
# Epoch 438/500, Train_Loss: 0.22, Train_Accuracy: 0.84
# Epoch 439/500, Train_Loss: 0.23, Train_Accuracy: 0.88
# Epoch 440/500, Train_Loss: 0.26, Train_Accuracy: 0.84
# Epoch 441/500, Train_Loss: 0.50, Train_Accuracy: 0.72
# Epoch 442/500, Train_Loss: 0.51, Train_Accuracy: 0.75
# Epoch 443/500, Train_Loss: 0.42, Train_Accuracy: 0.88
# Epoch 444/500, Train_Loss: 0.52, Train_Accuracy: 0.72
# Epoch 445/500, Train_Loss: 0.31, Train_Accuracy: 0.81
# Epoch 446/500, Train_Loss: 0.43, Train_Accuracy: 0.78
# Epoch 447/500, Train_Loss: 0.61, Train_Accuracy: 0.81
# Epoch 448/500, Train_Loss: 0.65, Train_Accuracy: 0.72
# Epoch 449/500, Train_Loss: 0.34, Train_Accuracy: 0.78
# Epoch 450/500, Train_Loss: 0.42, Train_Accuracy: 0.75
# Epoch 451/500, Train_Loss: 0.28, Train_Accuracy: 0.88
# Epoch 452/500, Train_Loss: 0.57, Train_Accuracy: 0.78
# Epoch 453/500, Train_Loss: 0.32, Train_Accuracy: 0.81
# Epoch 454/500, Train_Loss: 0.51, Train_Accuracy: 0.72
# Epoch 455/500, Train_Loss: 0.48, Train_Accuracy: 0.81
# Epoch 456/500, Train_Loss: 0.41, Train_Accuracy: 0.75
# Epoch 457/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 458/500, Train_Loss: 0.35, Train_Accuracy: 0.78
# Epoch 459/500, Train_Loss: 0.34, Train_Accuracy: 0.84
# Epoch 460/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 461/500, Train_Loss: 0.51, Train_Accuracy: 0.78
# Epoch 462/500, Train_Loss: 0.35, Train_Accuracy: 0.75
# Epoch 463/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 464/500, Train_Loss: 0.44, Train_Accuracy: 0.69
# Epoch 465/500, Train_Loss: 0.45, Train_Accuracy: 0.81
# Epoch 466/500, Train_Loss: 0.55, Train_Accuracy: 0.75
# Epoch 467/500, Train_Loss: 0.56, Train_Accuracy: 0.66
# Epoch 468/500, Train_Loss: 0.34, Train_Accuracy: 0.75
# Epoch 469/500, Train_Loss: 0.34, Train_Accuracy: 0.75
# Epoch 470/500, Train_Loss: 0.53, Train_Accuracy: 0.75
# Epoch 471/500, Train_Loss: 0.46, Train_Accuracy: 0.81
# Epoch 472/500, Train_Loss: 0.36, Train_Accuracy: 0.88
# Epoch 473/500, Train_Loss: 0.40, Train_Accuracy: 0.78
# Epoch 474/500, Train_Loss: 0.36, Train_Accuracy: 0.84
# Epoch 475/500, Train_Loss: 0.40, Train_Accuracy: 0.84
# Epoch 476/500, Train_Loss: 0.35, Train_Accuracy: 0.84
# Epoch 477/500, Train_Loss: 0.51, Train_Accuracy: 0.72
# Epoch 478/500, Train_Loss: 0.46, Train_Accuracy: 0.75
# Epoch 479/500, Train_Loss: 0.40, Train_Accuracy: 0.84
# Epoch 480/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 481/500, Train_Loss: 0.29, Train_Accuracy: 0.88
# Epoch 482/500, Train_Loss: 0.60, Train_Accuracy: 0.66
# Epoch 483/500, Train_Loss: 0.43, Train_Accuracy: 0.75
# Epoch 484/500, Train_Loss: 0.42, Train_Accuracy: 0.78
# Epoch 485/500, Train_Loss: 0.55, Train_Accuracy: 0.75
# Epoch 486/500, Train_Loss: 0.49, Train_Accuracy: 0.78
# Epoch 487/500, Train_Loss: 0.32, Train_Accuracy: 0.81
# Epoch 488/500, Train_Loss: 0.42, Train_Accuracy: 0.69
# Epoch 489/500, Train_Loss: 0.50, Train_Accuracy: 0.72
# Epoch 490/500, Train_Loss: 0.46, Train_Accuracy: 0.81
# Epoch 491/500, Train_Loss: 0.30, Train_Accuracy: 0.81
# Epoch 492/500, Train_Loss: 0.27, Train_Accuracy: 0.84
# Epoch 493/500, Train_Loss: 0.37, Train_Accuracy: 0.81
# Epoch 494/500, Train_Loss: 0.33, Train_Accuracy: 0.81
# Epoch 495/500, Train_Loss: 0.45, Train_Accuracy: 0.75
# Epoch 496/500, Train_Loss: 0.40, Train_Accuracy: 0.81
# Epoch 497/500, Train_Loss: 0.34, Train_Accuracy: 0.88
# Epoch 498/500, Train_Loss: 0.34, Train_Accuracy: 0.81
# Epoch 499/500, Train_Loss: 0.39, Train_Accuracy: 0.78
# Epoch 500/500, Train_Loss: 0.25, Train_Accuracy: 0.91
